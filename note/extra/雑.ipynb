# %%
import pandas as pd
from pathlib import Path

raw_orbit_count = len(list(Path(r"E:\interim\step2_normalized").glob("*.csv")))
print(raw_orbit_count)

df_eq_orbit = pd.read_csv(r"E:\tables\orbit_eq_match_with_closest_time_dist\closest_time_dist_ver2.csv")
eq_orbit_count = len(df_eq_orbit)
print(eq_orbit_count)

df_orbit_200s = pd.read_csv(r"E:\tables\orbit_with_+-200s\SEA_analysis_eq_ob_ver3.csv")
orbit_200s_count = len(df_orbit_200s)
print(orbit_200s_count)

df_raw_eq = pd.read_csv(r"F:\external\eq_catalog\eq_m4.8above_depth40kmbelow_2004-2010.csv")
raw_eq_count = len(df_raw_eq)
print(raw_eq_count)

df_de__eq = pd.read_csv(r"E:\tables\earthquake_catalog\declustered\eq_m4.8above_depth40kmbelow_2004-2010_declustered_ver6.csv")
de_eq_count = len(df_de__eq)
print(de_eq_count)
# Out:
# 28367
# 267
# 228
# 16324
# 7132
